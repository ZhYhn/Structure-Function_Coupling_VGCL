# %%
import pandas as pd
import scipy.stats as stats
import pingouin as pg
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf

# %% [markdown]
# ### Mixed-effects model

# %%
data = pd.read_csv(r"D:\Download\SFC\SFC_HCP\4_Validation\individual_VGCL\sfc_network_individual.csv")

# %%
data[['subject_id', 'run']] = data['id'].str.extract(r'(\d+)_(r\d+_[LR]+)')
data = data.drop('id', axis=1)

# %%
data_long = pd.melt(data,
                    id_vars=['gender', 'age', 'subject_id', 'run'],
                    value_vars=data.columns[2:-2],
                    var_name='network',
                    value_name='sfc')

# %%
model1 = smf.mixedlm("sfc ~ C(network) + C(run) + C(Gender) + C(Age)", 
                     groups="subject_id", 
                     data=data_long)
result1 = model1.fit()
print(result1.summary())
# Out:
#                     Mixed Linear Model Regression Results
# =============================================================================
# Model:                   MixedLM        Dependent Variable:        sfc
# No. Observations:        79840          Method:                    REML
# No. Groups:              998            Scale:                     0.0158
# Min. group size:         80             Log-Likelihood:            49989.2145
# Max. group size:         80             Converged:                 Yes
# Mean group size:         80.0
# -----------------------------------------------------------------------------
#                                   Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# -----------------------------------------------------------------------------
# Intercept                          0.590    0.009  65.181 0.000  0.572  0.607
# C(network)[T.L Cingulo-opercular] -0.021    0.003  -7.368 0.000 -0.026 -0.015
# C(network)[T.L Default mode]      -0.061    0.003 -21.629 0.000 -0.066 -0.055
# C(network)[T.L Dorsal attention]   0.041    0.003  14.690 0.000  0.036  0.047
# C(network)[T.L Frontoparietal]    -0.043    0.003 -15.249 0.000 -0.048 -0.037
# C(network)[T.L Language]          -0.011    0.003  -4.002 0.000 -0.017 -0.006
# C(network)[T.L Multimodal]        -0.024    0.003  -8.442 0.000 -0.029 -0.018
# C(network)[T.L Orbito-affective]  -0.212    0.003 -75.320 0.000 -0.218 -0.207
# C(network)[T.L Somatomotor]        0.036    0.003  12.668 0.000  0.030  0.041
# C(network)[T.L Visual]             0.084    0.003  29.663 0.000  0.078  0.089
# C(network)[T.R Auditory]           0.017    0.003   6.099 0.000  0.012  0.023
# C(network)[T.R Cingulo-opercular]  0.002    0.003   0.871 0.384 -0.003  0.008
# C(network)[T.R Default mode]      -0.069    0.003 -24.595 0.000 -0.075 -0.064
# C(network)[T.R Dorsal attention]   0.060    0.003  21.438 0.000  0.055  0.066
# C(network)[T.R Frontoparietal]    -0.027    0.003  -9.732 0.000 -0.033 -0.022
# C(network)[T.R Language]          -0.024    0.003  -8.602 0.000 -0.030 -0.019
# C(network)[T.R Multimodal]        -0.034    0.003 -11.998 0.000 -0.039 -0.028
# C(network)[T.R Orbito-affective]  -0.202    0.003 -71.556 0.000 -0.207 -0.196
# C(network)[T.R Somatomotor]        0.022    0.003   7.774 0.000  0.016  0.027
# C(network)[T.R Visual]             0.103    0.003  36.397 0.000  0.097  0.108
# C(run)[T.r1_RL]                   -0.039    0.001 -31.255 0.000 -0.042 -0.037
# C(run)[T.r2_LR]                   -0.043    0.001 -34.460 0.000 -0.046 -0.041
# C(run)[T.r2_RL]                   -0.018    0.001 -14.161 0.000 -0.020 -0.015
# C(Gender)[T.M]                     0.049    0.007   6.776 0.000  0.035  0.063
# C(Age)[T.26-30]                   -0.022    0.009  -2.402 0.016 -0.041 -0.004
# C(Age)[T.31-35]                   -0.034    0.010  -3.496 0.000 -0.054 -0.015
# C(Age)[T.36+]                     -0.042    0.038  -1.102 0.270 -0.116  0.032
# subject_id Var                     0.012    0.004
# =============================================================================

# %%
model2 = smf.mixedlm("sfc ~ C(network) * C(Gender) + C(run) + C(Age)", 
                     groups="subject_id", 
                     data=data_long)
result2 = model2.fit()
print(result2.summary())
# Out:
#                            Mixed Linear Model Regression Results
# ============================================================================================
# Model:                        MixedLM             Dependent Variable:             sfc
# No. Observations:             79840               Method:                         REML
# No. Groups:                   998                 Scale:                          0.0158
# Min. group size:              80                  Log-Likelihood:                 49947.7876
# Max. group size:              80                  Converged:                      Yes
# Mean group size:              80.0
# --------------------------------------------------------------------------------------------
#                                                  Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------------------
# Intercept                                         0.591    0.009  64.016 0.000  0.572  0.609
# C(network)[T.L Cingulo-opercular]                -0.029    0.004  -7.500 0.000 -0.036 -0.021
# C(network)[T.L Default mode]                     -0.058    0.004 -15.051 0.000 -0.066 -0.050
# C(network)[T.L Dorsal attention]                  0.042    0.004  11.016 0.000  0.035  0.050
# C(network)[T.L Frontoparietal]                   -0.045    0.004 -11.551 0.000 -0.052 -0.037
# C(network)[T.L Language]                         -0.016    0.004  -4.144 0.000 -0.024 -0.008
# C(network)[T.L Multimodal]                       -0.029    0.004  -7.493 0.000 -0.036 -0.021
# C(network)[T.L Orbito-affective]                 -0.211    0.004 -54.731 0.000 -0.219 -0.204
# C(network)[T.L Somatomotor]                       0.035    0.004   8.983 0.000  0.027  0.042
# C(network)[T.L Visual]                            0.087    0.004  22.668 0.000  0.080  0.095
# C(network)[T.R Auditory]                          0.015    0.004   3.996 0.000  0.008  0.023
# C(network)[T.R Cingulo-opercular]                -0.001    0.004  -0.246 0.806 -0.009  0.007
# C(network)[T.R Default mode]                     -0.069    0.004 -17.875 0.000 -0.077 -0.061
# C(network)[T.R Dorsal attention]                  0.064    0.004  16.648 0.000  0.057  0.072
# C(network)[T.R Frontoparietal]                   -0.027    0.004  -7.101 0.000 -0.035 -0.020
# C(network)[T.R Language]                         -0.031    0.004  -8.010 0.000 -0.038 -0.023
# C(network)[T.R Multimodal]                       -0.040    0.004 -10.281 0.000 -0.047 -0.032
# C(network)[T.R Orbito-affective]                 -0.203    0.004 -52.563 0.000 -0.210 -0.195
# C(network)[T.R Somatomotor]                       0.020    0.004   5.075 0.000  0.012  0.027
# C(network)[T.R Visual]                            0.111    0.004  28.771 0.000  0.103  0.119
# C(Gender)[T.M]                                    0.047    0.008   5.696 0.000  0.031  0.063
# C(run)[T.r1_RL]                                  -0.039    0.001 -31.269 0.000 -0.042 -0.037
# C(run)[T.r2_LR]                                  -0.043    0.001 -34.475 0.000 -0.046 -0.041
# C(run)[T.r2_RL]                                  -0.018    0.001 -14.168 0.000 -0.020 -0.015
# C(Age)[T.26-30]                                  -0.022    0.009  -2.402 0.016 -0.041 -0.004
# C(Age)[T.31-35]                                  -0.034    0.010  -3.496 0.000 -0.054 -0.015
# C(Age)[T.36+]                                    -0.042    0.038  -1.102 0.270 -0.116  0.032
# C(network)[T.L Cingulo-opercular]:C(Gender)[T.M]  0.017    0.006   3.100 0.002  0.006  0.029
# C(network)[T.L Default mode]:C(Gender)[T.M]      -0.006    0.006  -1.094 0.274 -0.017  0.005
# C(network)[T.L Dorsal attention]:C(Gender)[T.M]  -0.002    0.006  -0.418 0.676 -0.013  0.009
# C(network)[T.L Frontoparietal]:C(Gender)[T.M]     0.003    0.006   0.603 0.546 -0.008  0.014
# C(network)[T.L Language]:C(Gender)[T.M]           0.010    0.006   1.787 0.074 -0.001  0.021
# C(network)[T.L Multimodal]:C(Gender)[T.M]         0.011    0.006   1.941 0.052 -0.000  0.022
# C(network)[T.L Orbito-affective]:C(Gender)[T.M]  -0.002    0.006  -0.418 0.676 -0.013  0.009
# C(network)[T.L Somatomotor]:C(Gender)[T.M]        0.002    0.006   0.395 0.693 -0.009  0.013
# C(network)[T.L Visual]:C(Gender)[T.M]            -0.008    0.006  -1.465 0.143 -0.019  0.003
# C(network)[T.R Auditory]:C(Gender)[T.M]           0.004    0.006   0.672 0.502 -0.007  0.015
# C(network)[T.R Cingulo-opercular]:C(Gender)[T.M]  0.007    0.006   1.290 0.197 -0.004  0.018
# C(network)[T.R Default mode]:C(Gender)[T.M]      -0.001    0.006  -0.132 0.895 -0.012  0.010
# C(network)[T.R Dorsal attention]:C(Gender)[T.M]  -0.008    0.006  -1.447 0.148 -0.019  0.003
# C(network)[T.R Frontoparietal]:C(Gender)[T.M]    -0.000    0.006  -0.011 0.991 -0.011  0.011
# C(network)[T.R Language]:C(Gender)[T.M]           0.014    0.006   2.526 0.012  0.003  0.025
# C(network)[T.R Multimodal]:C(Gender)[T.M]         0.013    0.006   2.220 0.026  0.001  0.024
# C(network)[T.R Orbito-affective]:C(Gender)[T.M]   0.002    0.006   0.433 0.665 -0.009  0.014
# C(network)[T.R Somatomotor]:C(Gender)[T.M]        0.005    0.006   0.883 0.377 -0.006  0.016
# C(network)[T.R Visual]:C(Gender)[T.M]            -0.018    0.006  -3.198 0.001 -0.029 -0.007
# subject_id Var                                    0.012    0.004
# ============================================================================================

# %%
model3 = smf.mixedlm("sfc ~ C(network) * C(Age) + C(run) + C(Gender)", 
                     groups="subject_id", 
                     data=data_long)
result3 = model3.fit()
print(result3.summary())
# Out:
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                         MixedLM             Dependent Variable:             sfc
# No. Observations:              79840               Method:                         REML
# No. Groups:                    998                 Scale:                          0.0158
# Min. group size:               80                  Log-Likelihood:                 49818.7187
# Max. group size:               80                  Converged:                      Yes
# Mean group size:               80.0
# ---------------------------------------------------------------------------------------------
#                                                   Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                          0.591    0.010  60.527 0.000  0.572  0.610
# C(network)[T.L Cingulo-opercular]                 -0.023    0.006  -3.828 0.000 -0.035 -0.011
# C(network)[T.L Default mode]                      -0.066    0.006 -10.902 0.000 -0.078 -0.054
# C(network)[T.L Dorsal attention]                   0.040    0.006   6.718 0.000  0.029  0.052
# C(network)[T.L Frontoparietal]                    -0.049    0.006  -8.112 0.000 -0.061 -0.037
# C(network)[T.L Language]                          -0.007    0.006  -1.214 0.225 -0.019  0.004
# C(network)[T.L Multimodal]                        -0.019    0.006  -3.088 0.002 -0.030 -0.007
# C(network)[T.L Orbito-affective]                  -0.216    0.006 -35.869 0.000 -0.228 -0.204
# C(network)[T.L Somatomotor]                        0.036    0.006   6.030 0.000  0.025  0.048
# C(network)[T.L Visual]                             0.080    0.006  13.308 0.000  0.068  0.092
# C(network)[T.R Auditory]                           0.019    0.006   3.223 0.001  0.008  0.031
# C(network)[T.R Cingulo-opercular]                  0.001    0.006   0.152 0.879 -0.011  0.013
# C(network)[T.R Default mode]                      -0.069    0.006 -11.530 0.000 -0.081 -0.058
# C(network)[T.R Dorsal attention]                   0.055    0.006   9.102 0.000  0.043  0.067
# C(network)[T.R Frontoparietal]                    -0.034    0.006  -5.689 0.000 -0.046 -0.022
# C(network)[T.R Language]                          -0.026    0.006  -4.236 0.000 -0.037 -0.014
# C(network)[T.R Multimodal]                        -0.026    0.006  -4.317 0.000 -0.038 -0.014
# C(network)[T.R Orbito-affective]                  -0.201    0.006 -33.300 0.000 -0.213 -0.189
# C(network)[T.R Somatomotor]                        0.025    0.006   4.141 0.000  0.013  0.037
# C(network)[T.R Visual]                             0.090    0.006  14.860 0.000  0.078  0.101
# C(Age)[T.26-30]                                   -0.024    0.011  -2.301 0.021 -0.045 -0.004
# C(Age)[T.31-35]                                   -0.036    0.011  -3.251 0.001 -0.058 -0.014
# C(Age)[T.36+]                                     -0.013    0.043  -0.294 0.769 -0.097  0.072
# C(run)[T.r1_RL]                                   -0.039    0.001 -31.264 0.000 -0.042 -0.037
# C(run)[T.r2_LR]                                   -0.043    0.001 -34.469 0.000 -0.046 -0.041
# C(run)[T.r2_RL]                                   -0.018    0.001 -14.165 0.000 -0.020 -0.015
# C(Gender)[T.M]                                     0.049    0.007   6.776 0.000  0.035  0.063
# C(network)[T.L Cingulo-opercular]:C(Age)[T.26-30]  0.003    0.007   0.400 0.689 -0.012  0.017
# C(network)[T.L Default mode]:C(Age)[T.26-30]       0.003    0.007   0.419 0.675 -0.011  0.018
# C(network)[T.L Dorsal attention]:C(Age)[T.26-30]  -0.000    0.007  -0.054 0.957 -0.015  0.014
# C(network)[T.L Frontoparietal]:C(Age)[T.26-30]     0.013    0.007   1.716 0.086 -0.002  0.027
# C(network)[T.L Language]:C(Age)[T.26-30]          -0.007    0.007  -0.912 0.362 -0.021  0.008
# C(network)[T.L Multimodal]:C(Age)[T.26-30]        -0.004    0.007  -0.578 0.563 -0.019  0.010
# C(network)[T.L Orbito-affective]:C(Age)[T.26-30]   0.004    0.007   0.585 0.559 -0.010  0.019
# C(network)[T.L Somatomotor]:C(Age)[T.26-30]        0.001    0.007   0.139 0.890 -0.013  0.016
# C(network)[T.L Visual]:C(Age)[T.26-30]            -0.002    0.007  -0.250 0.803 -0.016  0.013
# C(network)[T.R Auditory]:C(Age)[T.26-30]           0.005    0.007   0.625 0.532 -0.010  0.019
# C(network)[T.R Cingulo-opercular]:C(Age)[T.26-30]  0.001    0.007   0.150 0.880 -0.013  0.016
# C(network)[T.R Default mode]:C(Age)[T.26-30]      -0.002    0.007  -0.292 0.770 -0.017  0.012
# C(network)[T.R Dorsal attention]:C(Age)[T.26-30]   0.006    0.007   0.790 0.430 -0.009  0.020
# C(network)[T.R Frontoparietal]:C(Age)[T.26-30]     0.014    0.007   1.844 0.065 -0.001  0.028
# C(network)[T.R Language]:C(Age)[T.26-30]           0.006    0.007   0.770 0.441 -0.009  0.020
# C(network)[T.R Multimodal]:C(Age)[T.26-30]        -0.009    0.007  -1.237 0.216 -0.024  0.005
# C(network)[T.R Orbito-affective]:C(Age)[T.26-30]  -0.002    0.007  -0.288 0.773 -0.017  0.012
# C(network)[T.R Somatomotor]:C(Age)[T.26-30]       -0.000    0.007  -0.065 0.948 -0.015  0.014
# C(network)[T.R Visual]:C(Age)[T.26-30]             0.013    0.007   1.797 0.072 -0.001  0.028
# C(network)[T.L Cingulo-opercular]:C(Age)[T.31-35]  0.004    0.008   0.500 0.617 -0.011  0.019
# C(network)[T.L Default mode]:C(Age)[T.31-35]       0.011    0.008   1.424 0.154 -0.004  0.026
# C(network)[T.L Dorsal attention]:C(Age)[T.31-35]   0.003    0.008   0.385 0.700 -0.012  0.018
# C(network)[T.L Frontoparietal]:C(Age)[T.31-35]     0.002    0.008   0.322 0.747 -0.013  0.018
# C(network)[T.L Language]:C(Age)[T.31-35]          -0.002    0.008  -0.253 0.800 -0.017  0.013
# C(network)[T.L Multimodal]:C(Age)[T.31-35]        -0.009    0.008  -1.218 0.223 -0.025  0.006
# C(network)[T.L Orbito-affective]:C(Age)[T.31-35]   0.007    0.008   0.928 0.353 -0.008  0.022
# C(network)[T.L Somatomotor]:C(Age)[T.31-35]       -0.002    0.008  -0.254 0.799 -0.017  0.013
# C(network)[T.L Visual]:C(Age)[T.31-35]             0.012    0.008   1.565 0.118 -0.003  0.027
# C(network)[T.R Auditory]:C(Age)[T.31-35]          -0.011    0.008  -1.427 0.154 -0.026  0.004
# C(network)[T.R Cingulo-opercular]:C(Age)[T.31-35]  0.004    0.008   0.502 0.616 -0.011  0.019
# C(network)[T.R Default mode]:C(Age)[T.31-35]       0.005    0.008   0.600 0.548 -0.010  0.020
# C(network)[T.R Dorsal attention]:C(Age)[T.31-35]   0.009    0.008   1.142 0.253 -0.006  0.024
# C(network)[T.R Frontoparietal]:C(Age)[T.31-35]     0.004    0.008   0.569 0.569 -0.011  0.020
# C(network)[T.R Language]:C(Age)[T.31-35]          -0.002    0.008  -0.249 0.803 -0.017  0.013
# C(network)[T.R Multimodal]:C(Age)[T.31-35]        -0.010    0.008  -1.312 0.189 -0.025  0.005
# C(network)[T.R Orbito-affective]:C(Age)[T.31-35]   0.001    0.008   0.092 0.926 -0.014  0.016
# C(network)[T.R Somatomotor]:C(Age)[T.31-35]       -0.007    0.008  -0.910 0.363 -0.022  0.008
# C(network)[T.R Visual]:C(Age)[T.31-35]             0.021    0.008   2.679 0.007  0.006  0.036
# C(network)[T.L Cingulo-opercular]:C(Age)[T.36+]   -0.031    0.030  -1.038 0.299 -0.091  0.028
# C(network)[T.L Default mode]:C(Age)[T.36+]        -0.037    0.030  -1.217 0.224 -0.096  0.022
# C(network)[T.L Dorsal attention]:C(Age)[T.36+]     0.006    0.030   0.201 0.841 -0.053  0.065
# C(network)[T.L Frontoparietal]:C(Age)[T.36+]      -0.043    0.030  -1.414 0.157 -0.102  0.017
# C(network)[T.L Language]:C(Age)[T.36+]            -0.043    0.030  -1.420 0.156 -0.102  0.016
# C(network)[T.L Multimodal]:C(Age)[T.36+]          -0.013    0.030  -0.424 0.672 -0.072  0.047
# C(network)[T.L Orbito-affective]:C(Age)[T.36+]    -0.039    0.030  -1.291 0.197 -0.098  0.020
# C(network)[T.L Somatomotor]:C(Age)[T.36+]         -0.046    0.030  -1.525 0.127 -0.105  0.013
# C(network)[T.L Visual]:C(Age)[T.36+]               0.003    0.030   0.105 0.917 -0.056  0.062
# C(network)[T.R Auditory]:C(Age)[T.36+]            -0.051    0.030  -1.670 0.095 -0.110  0.009
# C(network)[T.R Cingulo-opercular]:C(Age)[T.36+]   -0.030    0.030  -0.984 0.325 -0.089  0.030
# C(network)[T.R Default mode]:C(Age)[T.36+]        -0.051    0.030  -1.700 0.089 -0.111  0.008
# C(network)[T.R Dorsal attention]:C(Age)[T.36+]     0.002    0.030   0.050 0.960 -0.058  0.061
# C(network)[T.R Frontoparietal]:C(Age)[T.36+]      -0.055    0.030  -1.833 0.067 -0.115  0.004
# C(network)[T.R Language]:C(Age)[T.36+]            -0.055    0.030  -1.830 0.067 -0.115  0.004
# C(network)[T.R Multimodal]:C(Age)[T.36+]          -0.043    0.030  -1.409 0.159 -0.102  0.017
# C(network)[T.R Orbito-affective]:C(Age)[T.36+]    -0.027    0.030  -0.901 0.368 -0.087  0.032
# C(network)[T.R Somatomotor]:C(Age)[T.36+]         -0.049    0.030  -1.620 0.105 -0.108  0.010
# C(network)[T.R Visual]:C(Age)[T.36+]               0.022    0.030   0.714 0.475 -0.038  0.081
# subject_id Var                                     0.012    0.004
# =============================================================================================

# %%
model4 = smf.mixedlm("sfc ~ C(network) + C(run) + C(gender) + C(age) + C(network):C(gender) + C(network):C(age) + C(network):C(run)", 
                     groups="subject_id", 
                     data=data_long)
result4 = model4.fit()
print(result4.summary())
# Out:
# D:\anaconda\envs\Pytorch\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
#                             Mixed Linear Model Regression Results
# =============================================================================================
# Model:                        MixedLM             Dependent Variable:             sfc
# No. Observations:             79840               Method:                         REML
# No. Groups:                   998                 Scale:                          0.0032
# Min. group size:              80                  Log-Likelihood:                 114354.9033
# Max. group size:              80                  Converged:                      Yes
# Mean group size:              80.0
# ---------------------------------------------------------------------------------------------
#                                                   Coef.  Std.Err.    z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------------------
# Intercept                                          0.623    0.003 192.047 0.000  0.617  0.629
# C(network)[T.L Cingulo-opercular]                 -0.056    0.004 -14.554 0.000 -0.063 -0.048
# C(network)[T.L Default mode]                      -0.045    0.004 -11.838 0.000 -0.053 -0.038
# C(network)[T.L Dorsal attention]                  -0.006    0.004  -1.541 0.123 -0.013  0.002
# C(network)[T.L Frontoparietal]                    -0.042    0.004 -10.977 0.000 -0.050 -0.035
# C(network)[T.L Language]                          -0.013    0.004  -3.316 0.001 -0.020 -0.005
# C(network)[T.L Multimodal]                        -0.060    0.004 -15.539 0.000 -0.067 -0.052
# C(network)[T.L Orbito-affective]                  -0.162    0.004 -42.198 0.000 -0.169 -0.154
# C(network)[T.L Somatomotor]                        0.013    0.004   3.420 0.001  0.006  0.021
# C(network)[T.L Visual]                             0.019    0.004   5.001 0.000  0.012  0.027
# C(network)[T.R Auditory]                          -0.007    0.004  -1.893 0.058 -0.015  0.000
# C(network)[T.R Cingulo-opercular]                 -0.045    0.004 -11.673 0.000 -0.052 -0.037
# C(network)[T.R Default mode]                      -0.067    0.004 -17.444 0.000 -0.074 -0.059
# C(network)[T.R Dorsal attention]                  -0.003    0.004  -0.735 0.462 -0.010  0.005
# C(network)[T.R Frontoparietal]                    -0.056    0.004 -14.654 0.000 -0.064 -0.049
# C(network)[T.R Language]                          -0.050    0.004 -12.995 0.000 -0.057 -0.042
# C(network)[T.R Multimodal]                        -0.058    0.004 -15.043 0.000 -0.065 -0.050
# C(network)[T.R Orbito-affective]                  -0.166    0.004 -43.204 0.000 -0.173 -0.158
# C(network)[T.R Somatomotor]                        0.011    0.004   2.779 0.005  0.003  0.018
# C(network)[T.R Visual]                             0.038    0.004   9.852 0.000  0.030  0.045
# C(run)[T.r1_RL]                                   -0.031    0.003 -12.254 0.000 -0.036 -0.026
# C(run)[T.r2_LR]                                   -0.009    0.003  -3.529 0.000 -0.014 -0.004
# C(run)[T.r2_RL]                                   -0.008    0.003  -3.244 0.001 -0.013 -0.003
# C(gender)[T.M]                                     0.001    0.002   0.318 0.750 -0.004  0.005
# C(age)[T.26-30]                                   -0.002    0.003  -0.694 0.488 -0.008  0.004
# C(age)[T.31-35]                                   -0.001    0.003  -0.430 0.667 -0.008  0.005
# C(age)[T.36+]                                      0.021    0.012   1.735 0.083 -0.003  0.045
# C(network)[T.L Cingulo-opercular]:C(gender)[T.M]   0.009    0.003   3.655 0.000  0.004  0.014
# C(network)[T.L Default mode]:C(gender)[T.M]       -0.004    0.003  -1.545 0.122 -0.009  0.001
# C(network)[T.L Dorsal attention]:C(gender)[T.M]    0.004    0.003   1.575 0.115 -0.001  0.009
# C(network)[T.L Frontoparietal]:C(gender)[T.M]     -0.003    0.003  -1.012 0.312 -0.008  0.002
# C(network)[T.L Language]:C(gender)[T.M]            0.009    0.003   3.340 0.001  0.004  0.014
# C(network)[T.L Multimodal]:C(gender)[T.M]          0.002    0.003   0.905 0.365 -0.003  0.007
# C(network)[T.L Orbito-affective]:C(gender)[T.M]   -0.012    0.003  -4.811 0.000 -0.017 -0.007
# C(network)[T.L Somatomotor]:C(gender)[T.M]         0.008    0.003   2.933 0.003  0.003  0.013
# C(network)[T.L Visual]:C(gender)[T.M]              0.008    0.003   3.053 0.002  0.003  0.013
# C(network)[T.R Auditory]:C(gender)[T.M]           -0.000    0.003  -0.106 0.916 -0.005  0.005
# C(network)[T.R Cingulo-opercular]:C(gender)[T.M]   0.009    0.003   3.482 0.000  0.004  0.014
# C(network)[T.R Default mode]:C(gender)[T.M]       -0.004    0.003  -1.501 0.133 -0.009  0.001
# C(network)[T.R Dorsal attention]:C(gender)[T.M]    0.004    0.003   1.582 0.114 -0.001  0.009
# C(network)[T.R Frontoparietal]:C(gender)[T.M]     -0.003    0.003  -1.210 0.226 -0.008  0.002
# C(network)[T.R Language]:C(gender)[T.M]            0.005    0.003   1.984 0.047  0.000  0.010
# C(network)[T.R Multimodal]:C(gender)[T.M]          0.008    0.003   3.271 0.001  0.003  0.013
# C(network)[T.R Orbito-affective]:C(gender)[T.M]   -0.007    0.003  -2.805 0.005 -0.012 -0.002
# C(network)[T.R Somatomotor]:C(gender)[T.M]         0.009    0.003   3.432 0.001  0.004  0.014
# C(network)[T.R Visual]:C(gender)[T.M]              0.009    0.003   3.434 0.001  0.004  0.014
# C(network)[T.L Cingulo-opercular]:C(age)[T.26-30]  0.002    0.003   0.690 0.490 -0.004  0.009
# C(network)[T.L Default mode]:C(age)[T.26-30]      -0.001    0.003  -0.437 0.662 -0.008  0.005
# C(network)[T.L Dorsal attention]:C(age)[T.26-30]  -0.010    0.003  -2.872 0.004 -0.016 -0.003
# C(network)[T.L Frontoparietal]:C(age)[T.26-30]     0.004    0.003   1.056 0.291 -0.003  0.010
# C(network)[T.L Language]:C(age)[T.26-30]          -0.005    0.003  -1.607 0.108 -0.012  0.001
# C(network)[T.L Multimodal]:C(age)[T.26-30]        -0.003    0.003  -0.988 0.323 -0.010  0.003
# C(network)[T.L Orbito-affective]:C(age)[T.26-30]   0.001    0.003   0.431 0.666 -0.005  0.008
# C(network)[T.L Somatomotor]:C(age)[T.26-30]       -0.005    0.003  -1.602 0.109 -0.012  0.001
# C(network)[T.L Visual]:C(age)[T.26-30]            -0.001    0.003  -0.423 0.673 -0.008  0.005
# C(network)[T.R Auditory]:C(age)[T.26-30]          -0.002    0.003  -0.616 0.538 -0.009  0.004
# C(network)[T.R Cingulo-opercular]:C(age)[T.26-30]  0.000    0.003   0.081 0.935 -0.006  0.007
# C(network)[T.R Default mode]:C(age)[T.26-30]       0.000    0.003   0.055 0.956 -0.006  0.007
# C(network)[T.R Dorsal attention]:C(age)[T.26-30]  -0.011    0.003  -3.160 0.002 -0.017 -0.004
# C(network)[T.R Frontoparietal]:C(age)[T.26-30]     0.005    0.003   1.379 0.168 -0.002  0.011
# C(network)[T.R Language]:C(age)[T.26-30]          -0.000    0.003  -0.085 0.932 -0.007  0.006
# C(network)[T.R Multimodal]:C(age)[T.26-30]        -0.002    0.003  -0.709 0.478 -0.009  0.004
# C(network)[T.R Orbito-affective]:C(age)[T.26-30]   0.005    0.003   1.605 0.108 -0.001  0.012
# C(network)[T.R Somatomotor]:C(age)[T.26-30]       -0.007    0.003  -1.946 0.052 -0.013  0.000
# C(network)[T.R Visual]:C(age)[T.26-30]            -0.007    0.003  -1.989 0.047 -0.013 -0.000
# C(network)[T.L Cingulo-opercular]:C(age)[T.31-35]  0.003    0.004   0.942 0.346 -0.004  0.010
# C(network)[T.L Default mode]:C(age)[T.31-35]       0.000    0.004   0.028 0.977 -0.007  0.007
# C(network)[T.L Dorsal attention]:C(age)[T.31-35]  -0.008    0.004  -2.153 0.031 -0.014 -0.001
# C(network)[T.L Frontoparietal]:C(age)[T.31-35]     0.003    0.004   0.855 0.393 -0.004  0.010
# C(network)[T.L Language]:C(age)[T.31-35]          -0.005    0.004  -1.528 0.127 -0.012  0.002
# C(network)[T.L Multimodal]:C(age)[T.31-35]        -0.003    0.004  -0.778 0.437 -0.010  0.004
# C(network)[T.L Orbito-affective]:C(age)[T.31-35]   0.001    0.004   0.222 0.825 -0.006  0.008
# C(network)[T.L Somatomotor]:C(age)[T.31-35]       -0.008    0.004  -2.238 0.025 -0.015 -0.001
# C(network)[T.L Visual]:C(age)[T.31-35]            -0.001    0.004  -0.343 0.732 -0.008  0.006
# C(network)[T.R Auditory]:C(age)[T.31-35]          -0.003    0.004  -0.931 0.352 -0.010  0.004
# C(network)[T.R Cingulo-opercular]:C(age)[T.31-35]  0.002    0.004   0.438 0.661 -0.005  0.008
# C(network)[T.R Default mode]:C(age)[T.31-35]       0.003    0.004   0.903 0.367 -0.004  0.010
# C(network)[T.R Dorsal attention]:C(age)[T.31-35]  -0.010    0.004  -2.949 0.003 -0.017 -0.003
# C(network)[T.R Frontoparietal]:C(age)[T.31-35]     0.006    0.004   1.626 0.104 -0.001  0.013
# C(network)[T.R Language]:C(age)[T.31-35]           0.001    0.004   0.326 0.744 -0.006  0.008
# C(network)[T.R Multimodal]:C(age)[T.31-35]        -0.005    0.004  -1.344 0.179 -0.012  0.002
# C(network)[T.R Orbito-affective]:C(age)[T.31-35]   0.007    0.004   2.022 0.043  0.000  0.014
# C(network)[T.R Somatomotor]:C(age)[T.31-35]       -0.008    0.004  -2.380 0.017 -0.015 -0.001
# C(network)[T.R Visual]:C(age)[T.31-35]            -0.004    0.004  -1.184 0.236 -0.011  0.003
# C(network)[T.L Cingulo-opercular]:C(age)[T.36+]   -0.026    0.014  -1.900 0.057 -0.052  0.001
# C(network)[T.L Default mode]:C(age)[T.36+]        -0.028    0.014  -2.096 0.036 -0.055 -0.002
# C(network)[T.L Dorsal attention]:C(age)[T.36+]    -0.017    0.014  -1.257 0.209 -0.044  0.010
# C(network)[T.L Frontoparietal]:C(age)[T.36+]      -0.027    0.014  -1.987 0.047 -0.054 -0.000
# C(network)[T.L Language]:C(age)[T.36+]            -0.033    0.014  -2.411 0.016 -0.059 -0.006
# C(network)[T.L Multimodal]:C(age)[T.36+]          -0.017    0.014  -1.286 0.199 -0.044  0.009
# C(network)[T.L Orbito-affective]:C(age)[T.36+]    -0.030    0.014  -2.217 0.027 -0.057 -0.003
# C(network)[T.L Somatomotor]:C(age)[T.36+]         -0.020    0.014  -1.510 0.131 -0.047  0.006
# C(network)[T.L Visual]:C(age)[T.36+]              -0.015    0.014  -1.131 0.258 -0.042  0.011
# C(network)[T.R Auditory]:C(age)[T.36+]            -0.043    0.014  -3.202 0.001 -0.070 -0.017
# C(network)[T.R Cingulo-opercular]:C(age)[T.36+]   -0.033    0.014  -2.405 0.016 -0.059 -0.006
# C(network)[T.R Default mode]:C(age)[T.36+]        -0.018    0.014  -1.299 0.194 -0.044  0.009
# C(network)[T.R Dorsal attention]:C(age)[T.36+]    -0.030    0.014  -2.209 0.027 -0.057 -0.003
# C(network)[T.R Frontoparietal]:C(age)[T.36+]      -0.025    0.014  -1.855 0.064 -0.052  0.001
# C(network)[T.R Language]:C(age)[T.36+]            -0.041    0.014  -3.046 0.002 -0.068 -0.015
# C(network)[T.R Multimodal]:C(age)[T.36+]          -0.010    0.014  -0.726 0.468 -0.036  0.017
# C(network)[T.R Orbito-affective]:C(age)[T.36+]    -0.037    0.014  -2.748 0.006 -0.064 -0.011
# C(network)[T.R Somatomotor]:C(age)[T.36+]         -0.019    0.014  -1.423 0.155 -0.046  0.007
# C(network)[T.R Visual]:C(age)[T.36+]              -0.016    0.014  -1.146 0.252 -0.042  0.011
# C(network)[T.L Cingulo-opercular]:C(run)[T.r1_RL]  0.014    0.004   3.828 0.000  0.007  0.021
# C(network)[T.L Default mode]:C(run)[T.r1_RL]       0.028    0.004   7.772 0.000  0.021  0.035
# C(network)[T.L Dorsal attention]:C(run)[T.r1_RL]   0.013    0.004   3.785 0.000  0.007  0.020
# C(network)[T.L Frontoparietal]:C(run)[T.r1_RL]     0.032    0.004   8.936 0.000  0.025  0.039
# C(network)[T.L Language]:C(run)[T.r1_RL]           0.029    0.004   8.034 0.000  0.022  0.036
# C(network)[T.L Multimodal]:C(run)[T.r1_RL]         0.022    0.004   6.058 0.000  0.015  0.029
# C(network)[T.L Orbito-affective]:C(run)[T.r1_RL]   0.038    0.004  10.689 0.000  0.031  0.045
# C(network)[T.L Somatomotor]:C(run)[T.r1_RL]        0.011    0.004   3.046 0.002  0.004  0.018
# C(network)[T.L Visual]:C(run)[T.r1_RL]             0.021    0.004   5.836 0.000  0.014  0.028
# C(network)[T.R Auditory]:C(run)[T.r1_RL]           0.023    0.004   6.331 0.000  0.016  0.030
# C(network)[T.R Cingulo-opercular]:C(run)[T.r1_RL]  0.022    0.004   6.199 0.000  0.015  0.029
# C(network)[T.R Default mode]:C(run)[T.r1_RL]       0.039    0.004  10.938 0.000  0.032  0.046
# C(network)[T.R Dorsal attention]:C(run)[T.r1_RL]   0.025    0.004   7.003 0.000  0.018  0.032
# C(network)[T.R Frontoparietal]:C(run)[T.r1_RL]     0.044    0.004  12.411 0.000  0.037  0.051
# C(network)[T.R Language]:C(run)[T.r1_RL]           0.028    0.004   7.866 0.000  0.021  0.035
# C(network)[T.R Multimodal]:C(run)[T.r1_RL]         0.023    0.004   6.489 0.000  0.016  0.030
# C(network)[T.R Orbito-affective]:C(run)[T.r1_RL]   0.018    0.004   5.134 0.000  0.011  0.025
# C(network)[T.R Somatomotor]:C(run)[T.r1_RL]        0.014    0.004   3.803 0.000  0.007  0.021
# C(network)[T.R Visual]:C(run)[T.r1_RL]             0.026    0.004   7.231 0.000  0.019  0.033
# C(network)[T.L Cingulo-opercular]:C(run)[T.r2_LR]  0.003    0.004   0.759 0.448 -0.004  0.010
# C(network)[T.L Default mode]:C(run)[T.r2_LR]       0.012    0.004   3.400 0.001  0.005  0.019
# C(network)[T.L Dorsal attention]:C(run)[T.r2_LR]  -0.006    0.004  -1.710 0.087 -0.013  0.001
# C(network)[T.L Frontoparietal]:C(run)[T.r2_LR]     0.010    0.004   2.850 0.004  0.003  0.017
# C(network)[T.L Language]:C(run)[T.r2_LR]           0.007    0.004   2.032 0.042  0.000  0.014
# C(network)[T.L Multimodal]:C(run)[T.r2_LR]         0.003    0.004   0.956 0.339 -0.004  0.010
# C(network)[T.L Orbito-affective]:C(run)[T.r2_LR]   0.011    0.004   3.184 0.001  0.004  0.018
# C(network)[T.L Somatomotor]:C(run)[T.r2_LR]       -0.006    0.004  -1.679 0.093 -0.013  0.001
# C(network)[T.L Visual]:C(run)[T.r2_LR]             0.000    0.004   0.117 0.907 -0.007  0.007
# C(network)[T.R Auditory]:C(run)[T.r2_LR]          -0.003    0.004  -0.814 0.415 -0.010  0.004
# C(network)[T.R Cingulo-opercular]:C(run)[T.r2_LR] -0.001    0.004  -0.187 0.851 -0.008  0.006
# C(network)[T.R Default mode]:C(run)[T.r2_LR]       0.012    0.004   3.390 0.001  0.005  0.019
# C(network)[T.R Dorsal attention]:C(run)[T.r2_LR]  -0.005    0.004  -1.391 0.164 -0.012  0.002
# C(network)[T.R Frontoparietal]:C(run)[T.r2_LR]     0.009    0.004   2.481 0.013  0.002  0.016
# C(network)[T.R Language]:C(run)[T.r2_LR]           0.003    0.004   0.941 0.347 -0.004  0.010
# C(network)[T.R Multimodal]:C(run)[T.r2_LR]         0.000    0.004   0.040 0.968 -0.007  0.007
# C(network)[T.R Orbito-affective]:C(run)[T.r2_LR]   0.011    0.004   2.996 0.003  0.004  0.018
# C(network)[T.R Somatomotor]:C(run)[T.r2_LR]       -0.008    0.004  -2.167 0.030 -0.015 -0.001
# C(network)[T.R Visual]:C(run)[T.r2_LR]             0.000    0.004   0.046 0.964 -0.007  0.007
# C(network)[T.L Cingulo-opercular]:C(run)[T.r2_RL]  0.003    0.004   0.710 0.478 -0.004  0.010
# C(network)[T.L Default mode]:C(run)[T.r2_RL]       0.011    0.004   3.040 0.002  0.004  0.018
# C(network)[T.L Dorsal attention]:C(run)[T.r2_RL]  -0.002    0.004  -0.577 0.564 -0.009  0.005
# C(network)[T.L Frontoparietal]:C(run)[T.r2_RL]     0.001    0.004   0.352 0.725 -0.006  0.008
# C(network)[T.L Language]:C(run)[T.r2_RL]           0.006    0.004   1.639 0.101 -0.001  0.013
# C(network)[T.L Multimodal]:C(run)[T.r2_RL]         0.010    0.004   2.914 0.004  0.003  0.017
# C(network)[T.L Orbito-affective]:C(run)[T.r2_RL]   0.019    0.004   5.456 0.000  0.012  0.026
# C(network)[T.L Somatomotor]:C(run)[T.r2_RL]        0.008    0.004   2.190 0.029  0.001  0.015
# C(network)[T.L Visual]:C(run)[T.r2_RL]             0.005    0.004   1.333 0.183 -0.002  0.012
# C(network)[T.R Auditory]:C(run)[T.r2_RL]           0.021    0.004   5.803 0.000  0.014  0.028
# C(network)[T.R Cingulo-opercular]:C(run)[T.r2_RL]  0.010    0.004   2.924 0.003  0.003  0.017
# C(network)[T.R Default mode]:C(run)[T.r2_RL]       0.020    0.004   5.475 0.000  0.013  0.027
# C(network)[T.R Dorsal attention]:C(run)[T.r2_RL]   0.007    0.004   1.841 0.066 -0.000  0.014
# C(network)[T.R Frontoparietal]:C(run)[T.r2_RL]     0.013    0.004   3.589 0.000  0.006  0.020
# C(network)[T.R Language]:C(run)[T.r2_RL]           0.006    0.004   1.694 0.090 -0.001  0.013
# C(network)[T.R Multimodal]:C(run)[T.r2_RL]         0.004    0.004   1.009 0.313 -0.003  0.011
# C(network)[T.R Orbito-affective]:C(run)[T.r2_RL]  -0.001    0.004  -0.304 0.761 -0.008  0.006
# C(network)[T.R Somatomotor]:C(run)[T.r2_RL]        0.011    0.004   3.190 0.001  0.004  0.018
# C(network)[T.R Visual]:C(run)[T.r2_RL]             0.006    0.004   1.807 0.071 -0.001  0.013
# subject_id Var                                     0.001    0.000
# =============================================================================================

# %% [markdown]
# ### Calculate Pearson and Spearman correlation coefficients (for comparison of single-run and mixed-run)

# %%
from scipy.stats import spearmanr, pearsonr
import numpy as np

# %%
mixed = np.load(r"D:\Download\SFC\SFC_HCP\4_Validation\brain_region_difference_VGCL\sfc_group_network.npy")
r1_lr = np.load(r"D:\Download\SFC\SFC_HCP\4_Validation\single_run\REST1_LR\brain_region_difference_VGCL\sfc_ensemble_10_network.npy")
r1_rl = np.load(r"D:\Download\SFC\SFC_HCP\4_Validation\single_run\REST1_RL\brain_region_difference_VGCL\sfc_ensemble_10_network.npy")
r2_lr = np.load(r"D:\Download\SFC\SFC_HCP\4_Validation\single_run\REST2_LR\brain_region_difference_VGCL\sfc_ensemble_10_network.npy")
r2_rl = np.load(r"D:\Download\SFC\SFC_HCP\4_Validation\single_run\REST2_RL\brain_region_difference_VGCL\sfc_ensemble_10_network.npy")

# %%
def correlation_analysis(mixed_run, single_runs):
    results = {}
    for i, single_run in enumerate(single_runs):
        spearman_corr, spearman_p = spearmanr(mixed_run, single_run)
        pearson_corr, pearson_p = pearsonr(mixed_run, single_run)
        results[f'RUN_{i+1}'] = {
            'spearman_correlation': spearman_corr,
            'spearman_p_value': spearman_p,
            'pearson_correlation': pearson_corr,
            'pearson_p_value': pearson_p
        }
        print(f"RUN {i+1} & mixed-RUN:")
        print(f"  Spearman: {spearman_corr:.3f} (p={spearman_p})")
        print(f"  Pearson:  {pearson_corr:.3f} (p={pearson_p})")
    return results

correlation_results = correlation_analysis(mixed, [r1_lr, r1_rl, r2_lr, r2_rl])
# Out:
# RUN 1 & mixed-RUN:
#   Spearman: 0.871 (p=1.154775689467911e-112)
#   Pearson:  0.901 (p=5.487986250236029e-132)
# RUN 2 & mixed-RUN:
#   Spearman: 0.838 (p=2.9130954281452004e-96)
#   Pearson:  0.873 (p=5.8936162421010995e-114)
# RUN 3 & mixed-RUN:
#   Spearman: 0.892 (p=1.3604222082684397e-125)
#   Pearson:  0.913 (p=7.204109734908596e-142)
# RUN 4 & mixed-RUN:
#   Spearman: 0.732 (p=1.4680223709181659e-61)
#   Pearson:  0.818 (p=5.365349024192773e-88)

# %% [markdown]
# ### Intra-class Correlation Coefficient

# %%
bg = list(range(360)) * 5
model = ['mixed']*360 + ['r1_lr']*360 + ['r1_rl']*360 + ['r2_lr']*360 + ['r2_rl']*360
sfc = np.concatenate([mixed, r1_lr, r1_rl, r2_lr, r2_rl])
icc_data = np.array([np.array(bg), np.array(model), sfc]).T
icc_data = pd.DataFrame(icc_data, columns=['brain region', 'model', 'sfc'])
icc_data['sfc'] = icc_data['sfc'].astype(float)

# %%
icc_result = pg.intraclass_corr(data=icc_data, targets='brain region', raters='model', ratings='sfc')
print(icc_result)
# Out:
#     Type              Description       ICC          F  df1   df2  pval  \
# 0   ICC1   Single raters absolute  0.877967  36.972504  359  1440   0.0
# 1   ICC2     Single random raters  0.877974  37.062472  359  1436   0.0
# 2   ICC3      Single fixed raters  0.878234  37.062472  359  1436   0.0
# 3  ICC1k  Average raters absolute  0.972953  36.972504  359  1440   0.0
# 4  ICC2k    Average random raters  0.972955  37.062472  359  1436   0.0
# 5  ICC3k     Average fixed raters  0.973019  37.062472  359  1436   0.0
#
#           CI95%
# 0   [0.86, 0.9]
# 1   [0.86, 0.9]
# 2   [0.86, 0.9]
# 3  [0.97, 0.98]
# 4  [0.97, 0.98]
# 5  [0.97, 0.98]
